# %% [markdown]
# # Plotting cities and connections

# %%
# Complete list of US state capitals and their latitudes and longitudes
cities = {
    "Montgomery": (32.3770, -86.3006),
    #"Juneau": (58.3019, -134.4197),
    "Phoenix": (33.4484, -112.0740),
    "Little Rock": (34.7465, -92.2896),
    "Sacramento": (38.5816, -121.4944),
    "Denver": (39.7392, -104.9903),
    "Hartford": (41.7658, -72.6734),
    "Dover": (39.1582, -75.5244),
    "Tallahassee": (30.4383, -84.2807),
    "Atlanta": (33.7490, -84.3880),
    #"Honolulu": (21.3070, -157.8584),
    "Boise": (43.6150, -116.2023),
    "Springfield": (39.7983, -89.6446),
    "Indianapolis": (39.7684, -86.1581),
    "Des Moines": (41.5868, -93.6250),
    "Topeka": (39.0473, -95.6752),
    "Frankfort": (38.2009, -84.8733),
    "Baton Rouge": (30.4571, -91.1875),
    "Augusta": (44.3106, -69.7795),
    "Annapolis": (38.9784, -76.4922),
    "Boston": (42.3601, -71.0589),
    "Lansing": (42.7335, -84.5555),
    "St. Paul": (44.9537, -93.0900),
    "Jackson": (32.2988, -90.1848),
    "Jefferson City": (38.5767, -92.1735),
    "Helena": (46.5891, -112.0391),
    "Lincoln": (40.8136, -96.7026),
    "Carson City": (39.1638, -119.7674),
    "Concord": (43.2081, -71.5376),
    "Trenton": (40.2206, -74.7597),
    "Santa Fe": (35.6860, -105.9378),
    "Albany": (42.6526, -73.7562),
    "Raleigh": (35.7804, -78.6391),
    "Bismarck": (46.8083, -100.7837),
    "Columbus": (39.9612, -82.9988),
    "Oklahoma City": (35.4720, -97.5201),
    "Salem": (44.9429, -123.0351),
    "Harrisburg": (40.2732, -76.8867),
    "Providence": (41.8240, -71.4128),
    "Columbia": (34.0007, -81.0348),
    "Pierre": (44.3683, -100.3510),
    "Nashville": (36.1627, -86.7816),
    "Austin": (30.2672, -97.7431),
    "Salt Lake City": (40.7608, -111.8910),
    "Montpelier": (44.2601, -72.5754),
    "Richmond": (37.5407, -77.4360),
    "Olympia": (47.0379, -122.9007),
    "Charleston": (38.3498, -81.6326),
    "Madison": (43.0731, -89.4012),
    "Cheyenne": (41.1400, -104.8202)
}

# Initialize the map centered around the US
m_cities = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each city
for city, coords in cities.items():
    folium.Marker([coords[0], coords[1]], tooltip=city).add_to(m_cities)

m_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69d28623f751faa807a1437f7bc3823e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69d28623f751faa807a1437f7bc3823e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69d28623f751faa807a1437f7bc3823e = L.map(
#                 &quot;map_69d28623f751faa807a1437f7bc3823e&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5706699e067095e05fd2870e7c7ac092 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             var marker_95d5767009988c3ddad9005f8da92d77 = L.marker(
#                 [32.377, -86.3006],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_95d5767009988c3ddad9005f8da92d77.bindTooltip(
#                 `&lt;div&gt;
#                      Montgomery
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5890afabbe92499ecdcb92bf13fb0d1b = L.marker(
#                 [33.4484, -112.074],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_5890afabbe92499ecdcb92bf13fb0d1b.bindTooltip(
#                 `&lt;div&gt;
#                      Phoenix
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec2f1a5ee085f46c98fc41f9bbe29155 = L.marker(
#                 [34.7465, -92.2896],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_ec2f1a5ee085f46c98fc41f9bbe29155.bindTooltip(
#                 `&lt;div&gt;
#                      Little Rock
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d7df1a849ea3973edad5592fa1449e68 = L.marker(
#                 [38.5816, -121.4944],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_d7df1a849ea3973edad5592fa1449e68.bindTooltip(
#                 `&lt;div&gt;
#                      Sacramento
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a7b3e84cf302e96600c41320c9b064c4 = L.marker(
#                 [39.7392, -104.9903],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_a7b3e84cf302e96600c41320c9b064c4.bindTooltip(
#                 `&lt;div&gt;
#                      Denver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_905d4b70fb390527bfd95442b89c508b = L.marker(
#                 [41.7658, -72.6734],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_905d4b70fb390527bfd95442b89c508b.bindTooltip(
#                 `&lt;div&gt;
#                      Hartford
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6e4f89e99386ba5610da73149c7faba7 = L.marker(
#                 [39.1582, -75.5244],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_6e4f89e99386ba5610da73149c7faba7.bindTooltip(
#                 `&lt;div&gt;
#                      Dover
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b2652a7e6eecf4aaf9944749469f794 = L.marker(
#                 [30.4383, -84.2807],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_3b2652a7e6eecf4aaf9944749469f794.bindTooltip(
#                 `&lt;div&gt;
#                      Tallahassee
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_11b233a24af9c26cba46f96e5ba4cfeb = L.marker(
#                 [33.749, -84.388],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_11b233a24af9c26cba46f96e5ba4cfeb.bindTooltip(
#                 `&lt;div&gt;
#                      Atlanta
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aab974cc5e6b570b74450b0755ad2860 = L.marker(
#                 [43.615, -116.2023],
#                 {}
#             ).addTo(map_69d28623f751faa807a1437f7bc3823e);
#
#
#             marker_aab974cc5e6b570b74450b0755ad2860.bindTooltip(

# %%
# Function to compute distance between two lat-long points using the Haversine formula
def haversine(lat1, lon1, lat2, lon2):
    # Radius of the Earth in kilometers
    R = 6371.0
    
    # Convert degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Differences in coordinates
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    # Haversine formula
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    distance = R * c
    
    return distance

# Generate a distance matrix
n = len(cities)
distance_matrix = np.zeros((n, n))

for i, city1 in enumerate(cities):
    for j, city2 in enumerate(cities):
        distance_matrix[i, j] = haversine(cities[city1][0], cities[city1][1], cities[city2][0], cities[city2][1])

distance_matrix
# Out:
# array([[   0.        , 2402.70258243,  614.14652965, ...,  787.28813037,
#         1219.96358139, 1910.14071116],
#        [2402.70258243,    0.        , 1824.48493033, ..., 2782.41545441,
#         2240.0516226 , 1068.32561258],
#        [ 614.14652965, 1824.48493033,    0.        , ..., 1032.02899589,
#          958.84012181, 1306.69203092],
#        ...,
#        [ 787.28813037, 2782.41545441, 1032.02899589, ...,    0.        ,
#          838.76375709, 2000.5059997 ],
#        [1219.96358139, 2240.0516226 ,  958.84012181, ...,  838.76375709,
#            0.        , 1288.11796116],
#        [1910.14071116, 1068.32561258, 1306.69203092, ..., 2000.5059997 ,
#         1288.11796116,    0.        ]])

# %%
# Sample list of matchings (as city pairs)
matchings = [("Montgomery", "Phoenix"), 
             ("Little Rock", "Denver"), 
             ("Hartford", "Tallahassee"), 
             ("Dover", "Atlanta")]
import folium

# Initialize the map centered around the US
m = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each city
for city, coords in cities.items():
    folium.Marker([coords[0], coords[1]], tooltip=city).add_to(m)

# Add lines for matchings
for city1, city2 in matchings:
    folium.PolyLine([cities[city1], cities[city2]], color="red", weight=2.5, opacity=1).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97abc174270169967598fc00b79093bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97abc174270169967598fc00b79093bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97abc174270169967598fc00b79093bd = L.map(
#                 &quot;map_97abc174270169967598fc00b79093bd&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc98b3bf431fdc0a3fbeb3561f1054b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             var marker_6163bc056d32b3ff1dfd27a29b57a8d2 = L.marker(
#                 [32.377, -86.3006],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_6163bc056d32b3ff1dfd27a29b57a8d2.bindTooltip(
#                 `&lt;div&gt;
#                      Montgomery
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3876683339675f4576cae2721b63590 = L.marker(
#                 [33.4484, -112.074],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_c3876683339675f4576cae2721b63590.bindTooltip(
#                 `&lt;div&gt;
#                      Phoenix
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e01242617a8ce12685c36a6edacd5cad = L.marker(
#                 [34.7465, -92.2896],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_e01242617a8ce12685c36a6edacd5cad.bindTooltip(
#                 `&lt;div&gt;
#                      Little Rock
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10cb34b47ccd72dffcbbe57bd024949f = L.marker(
#                 [38.5816, -121.4944],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_10cb34b47ccd72dffcbbe57bd024949f.bindTooltip(
#                 `&lt;div&gt;
#                      Sacramento
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09b0d7fc9ebd4387244a5b1e9490d01c = L.marker(
#                 [39.7392, -104.9903],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_09b0d7fc9ebd4387244a5b1e9490d01c.bindTooltip(
#                 `&lt;div&gt;
#                      Denver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e02f29dfa25f91f8bc42b77fcda0f6ed = L.marker(
#                 [41.7658, -72.6734],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_e02f29dfa25f91f8bc42b77fcda0f6ed.bindTooltip(
#                 `&lt;div&gt;
#                      Hartford
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9da308c1b742096816d7d4b52be868b8 = L.marker(
#                 [39.1582, -75.5244],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_9da308c1b742096816d7d4b52be868b8.bindTooltip(
#                 `&lt;div&gt;
#                      Dover
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_abf8f560c379a351009205f31c6798a1 = L.marker(
#                 [30.4383, -84.2807],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_abf8f560c379a351009205f31c6798a1.bindTooltip(
#                 `&lt;div&gt;
#                      Tallahassee
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_627c40b3ac1bd9ba5a0ae7fef0a2ddcc = L.marker(
#                 [33.749, -84.388],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_627c40b3ac1bd9ba5a0ae7fef0a2ddcc.bindTooltip(
#                 `&lt;div&gt;
#                      Atlanta
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9f449e929d6b192b9b417373a476e8e4 = L.marker(
#                 [43.615, -116.2023],
#                 {}
#             ).addTo(map_97abc174270169967598fc00b79093bd);
#
#
#             marker_9f449e929d6b192b9b417373a476e8e4.bindTooltip(

# %% [markdown]
# # Some inital code

# %%
import gurobipy as gp
from itertools import combinations

# Recreate the model
m = gp.Model("CityMatching")

# Create variables
x = m.addVars(combinations(cities.keys(), 2),vtype=gp.GRB.BINARY, name="x")

# Create objective using the haversine formula to calculate distance
m.setObjective(gp.quicksum(haversine(cities[city1][0], cities[city1][1], 
                                     cities[city2][0], cities[city2][1]) * x[city1, city2] for city1, city2 in combinations(cities.keys(), 2)), 
               gp.GRB.MAXIMIZE) # possibly change to minimize

# Model is ready for further constraints and optimization
# .....


m.update()

m.write('CityMatching.lp')

m.optimize()
# Out:
# Warning: variable name "x[Montgomery,Little Rock]" has a space
# Warning: to let Gurobi read it back, use rlp format
# Gurobi Optimizer version 10.0.2 build v10.0.2rc0 (mac64[x86])
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 0 rows, 1128 columns and 0 nonzeros
# Model fingerprint: 0xbb6b80ba
# Variable types: 0 continuous, 1128 integer (1128 binary)
# Coefficient statistics:
#   Matrix range     [0e+00, 0e+00]
#   Objective range  [7e+01, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [0e+00, 0e+00]
# Found heuristic solution: objective 1888229.6387
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 1.88823e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.888229638668e+06, best bound 1.888229638668e+06, gap 0.0000%

# %%
"""
    Plot the solution of the matching problem on a folium map.
    
    Args:
    - model (gurobipy.Model): Solved Gurobi model object.
    - variables (dict): Dictionary of Gurobi variables for city pairs.
    - cities (dict): Dictionary with city names as keys and (latitude, longitude) as values.
    
    Returns:
- folium.Map: Map object with plotted cities and their matchings.
"""
# Create a new folium map
solution_map = folium.Map(location=[37.0902, -95.7129], zoom_start=4)

# Add markers for each city
for city, coords in cities.items():
    folium.Marker([coords[0], coords[1]], tooltip=city).add_to(solution_map)

# Extract pairs from the solution and draw lines
for (city1, city2) in combinations(cities.keys(), 2):
    if x[city1,city2].x > 0.5:  # If x[i,j] is set to 1 in the solution
        #print(city1, city2)
        folium.PolyLine([cities[city1], cities[city2]], color="red", weight=2.5, opacity=1).add_to(solution_map)

solution_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07c6862e4d2498570098191b3ff4445c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07c6862e4d2498570098191b3ff4445c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07c6862e4d2498570098191b3ff4445c = L.map(
#                 &quot;map_07c6862e4d2498570098191b3ff4445c&quot;,
#                 {
#                     center: [37.0902, -95.7129],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_541b25cb5a33e681399d7ef6fbb539fb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             var marker_2c0a604600170b96c91899188139f737 = L.marker(
#                 [32.377, -86.3006],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_2c0a604600170b96c91899188139f737.bindTooltip(
#                 `&lt;div&gt;
#                      Montgomery
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_104048c192ef97a726159915e43f1eac = L.marker(
#                 [33.4484, -112.074],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_104048c192ef97a726159915e43f1eac.bindTooltip(
#                 `&lt;div&gt;
#                      Phoenix
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_87d1e5e4b4633194404df821d936a8be = L.marker(
#                 [34.7465, -92.2896],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_87d1e5e4b4633194404df821d936a8be.bindTooltip(
#                 `&lt;div&gt;
#                      Little Rock
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6a80bfa46fcba61e70f357d8cf30018f = L.marker(
#                 [38.5816, -121.4944],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_6a80bfa46fcba61e70f357d8cf30018f.bindTooltip(
#                 `&lt;div&gt;
#                      Sacramento
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_47ed823840ea56fdc65fc6d3d0a1e35a = L.marker(
#                 [39.7392, -104.9903],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_47ed823840ea56fdc65fc6d3d0a1e35a.bindTooltip(
#                 `&lt;div&gt;
#                      Denver
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ddf679edb072d7cea72a2e72964278f0 = L.marker(
#                 [41.7658, -72.6734],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_ddf679edb072d7cea72a2e72964278f0.bindTooltip(
#                 `&lt;div&gt;
#                      Hartford
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bfc699e3b0480ff934984cd245f3403d = L.marker(
#                 [39.1582, -75.5244],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_bfc699e3b0480ff934984cd245f3403d.bindTooltip(
#                 `&lt;div&gt;
#                      Dover
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_850c2bb59d407c3c12761f439c474093 = L.marker(
#                 [30.4383, -84.2807],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_850c2bb59d407c3c12761f439c474093.bindTooltip(
#                 `&lt;div&gt;
#                      Tallahassee
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_242946f06fdf14a2aea8c7db36c1d2ed = L.marker(
#                 [33.749, -84.388],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_242946f06fdf14a2aea8c7db36c1d2ed.bindTooltip(
#                 `&lt;div&gt;
#                      Atlanta
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_10b0c7f8c16c82b7d12463956276ceeb = L.marker(
#                 [43.615, -116.2023],
#                 {}
#             ).addTo(map_07c6862e4d2498570098191b3ff4445c);
#
#
#             marker_10b0c7f8c16c82b7d12463956276ceeb.bindTooltip(
