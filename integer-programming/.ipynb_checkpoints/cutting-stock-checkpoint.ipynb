# %% [markdown]
# # Cutting Stock Problem
#
# ### General problem:
# You have an order come in for $d_i$ pipes of length $i$ for $i=1, \dots, k$.  How can you fill the order while cutting up the fewest number of pipes?
#
#
# ### Specific Example:
# A plumber stocks standard lengths of pipe, all of length 19 m. An order arrives for:
#
# - 12 lengths of 4m
# - 15 lengths of 5m
# - 22 lengths of 6m
#
# How should these lengths be cut from standard stock pipes so as to minimize
# the number of standard pipes used?

# %%
# Setup Data
L = [4,5,6] # Lengths of cuts of pipes needed
D = [12,15,22] # Demand for lengths of pipes
L_standard = 19 # Standard legnth of pipes that we can cut

d = [4,3,3] # number of times L[i] goes in to L_standard

# %% [markdown]
# ## First Model - Board Based

# %%
# Import Gurobi
import gurobipy as gp
from gurobipy import GRB
import math

# Create a new model
m = gp.Model("Cutting Stock - Board Based")

# Sets
num_lengths = len(L)
J = range(num_lengths) # index for number types of cuts we can do

num_boards_bound = int(sum([math.ceil(D[i]/d[i]) for i in range(num_lengths)])) # upper bound on the total number of boards that we need.

I = range(num_boards_bound)

# Create variables

# If we use board i, then x_i = 1
x = m.addVars(I, vtype=GRB.BINARY, name="x") 

# If we cut board i into 2 lengths of 4 m and 1 lenghth of 5m, then 
# y[i,0] = 2, y[i,1] = 1.
y = m.addVars(I,J, vtype = GRB.INTEGER, name = "y")

# Set objective - total number of boards used
m.setObjective(sum(x[i] for i in I ), GRB.MINIMIZE)

# Demand constraints:
m.addConstrs((sum(y[i,j] for i in I) >= D[j] for j in J)
             , "Demand")

#Feasible Board cuts
m.addConstrs((sum(L[j]*y[i,j] for j in J) <= L_standard for i in I)
             , "Feasible cuts")

# Activate board if it is cut
m.addConstrs((num_boards_bound*x[i] >= y[i,j] for i in I for j in J), "Turn on x[i]")

# Optimize model
m.optimize()

print("Optimal solution")
#for v in m.getVars():
    #print('%s: %g' % (v.varName, v.x))

print('Obj: %g' % m.objVal)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-08-26
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 67 rows, 64 columns and 192 nonzeros
# Model fingerprint: 0xee67ce00
# Variable types: 0 continuous, 64 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.00s
# Presolved: 67 rows, 64 columns, 192 nonzeros
# Variable types: 0 continuous, 64 integer (16 binary)
#
# Root relaxation: objective 7.333333e+00, 93 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    7.33333    0   43   15.00000    7.33333  51.1%     -    0s
# H    0     0                      14.0000000    7.33333  47.6%     -    0s
#      0     0    8.99414    0   38   14.00000    8.99414  35.8%     -    0s
#      0     0   11.13558    0   26   14.00000   11.13558  20.5%     -    0s
#      0     0   11.13558    0   28   14.00000   11.13558  20.5%     -    0s
#      0     0   11.34694    0   28   14.00000   11.34694  19.0%     -    0s
#      0     2   11.34694    0   28   14.00000   11.34694  19.0%     -    0s
#
# Explored 8 nodes (344 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 14 15 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Optimal solution
# Obj: 14

# %% [markdown]
# # Pattern Based Formulation

# %%
# Import Gurobi
import gurobipy as gp
from gurobipy import GRB
import math

# Create a new model
m = gp.Model("Cutting Stock - Board Based")


P = [[0,0,3],[0,1,2],[1,0,2],
     [0,2,1],[1,2,0],[2,2,0],
     [3,1,0],[4,0,0],[1,3,0],
     [3,0,1]]

num_patterns = len(P)

# Sets



I = range(num_patterns)

# Create variables

# If we use PATTERN i 10 times, then x_i = 10
x = m.addVars(I, vtype=GRB.INTEGER, name="x") 


# Set objective - total number of boards used
m.setObjective(sum(x[i] for i in I ), GRB.MINIMIZE)

# Demand constraints:
m.addConstrs((sum(P[i][j]*x[i] for i in I) >= D[j] for j in J)
             , "Demand")


# Optimize model
m.optimize()

print("Optimal solution")
print('Obj: %g' % m.objVal)
for i in I:
    print(f"# of patterns of type {P[i]} used is: {int(x[i].x)}")
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (mac64)
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x34ca604f
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+01, 4 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.88889    0    2   27.00000   13.88889  48.6%     -    0s
# H    0     0                      14.0000000   13.88889  0.79%     -    0s
#      0     0   13.88889    0    2   14.00000   13.88889  0.79%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 14 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Optimal solution
# Obj: 14
# # of patterns of type [0, 0, 3] used is: 6
# # of patterns of type [0, 1, 2] used is: 0
# # of patterns of type [1, 0, 2] used is: 1
# # of patterns of type [0, 2, 1] used is: 0
# # of patterns of type [1, 2, 0] used is: 0
# # of patterns of type [2, 2, 0] used is: 0
# # of patterns of type [3, 1, 0] used is: 0
# # of patterns of type [4, 0, 0] used is: 0
# # of patterns of type [1, 3, 0] used is: 5
# # of patterns of type [3, 0, 1] used is: 2

# %% [markdown]
# # Compare timing of formulations
#
# ### Make functions for each formulation

# %%
def board_based(D): 
    # Create a new model
    m = gp.Model("Cutting Stock - Board Based")

    # Sets
    num_lengths = len(L)
    J = range(num_lengths) # index for number types of cuts we can do

    num_boards_bound = int(sum([math.ceil(D[i]/d[i]) for i in range(num_lengths)])) # upper bound on the total number of boards that we need.

    I = range(num_boards_bound)

    # Create variables

    # If we use board i, then x_i = 1
    x = m.addVars(I, vtype=GRB.BINARY, name="x") 

    # If we cut board i into 2 lengths of 4 m and 1 lenghth of 5m, then 
    # y[i,0] = 2, y[i,1] = 1.
    y = m.addVars(I,J, vtype = GRB.INTEGER, name = "y")

    # Set objective - total number of boards used
    m.setObjective(sum(x[i] for i in I ), GRB.MINIMIZE)

    # Demand constraints:
    m.addConstrs((sum(y[i,j] for i in I) >= D[j] for j in J)
                 , "Demand")

    #Feasible Board cuts
    m.addConstrs((sum(L[j]*y[i,j] for j in J) <= L_standard for i in I)
                 , "Feasible cuts")

    # Activate board if it is cut
    m.addConstrs((num_boards_bound*x[i] >= y[i,j] for i in I for j in J), "Turn on x[i]")

    # Optimize model
    m.optimize()
    
def pattern_based(D):
    # Create a new model
    m = gp.Model("Cutting Stock - Board Based")


    P = [[0,0,3],[0,1,2],[1,0,2],
         [0,2,1],[1,2,0],[2,2,0],
         [3,1,0],[4,0,0],[1,3,0],
         [3,0,1]]

    num_patterns = len(P)

    # Sets

    I = range(num_patterns)

    # Create variables

    # If we use PATTERN i 10 times, then x_i = 10
    x = m.addVars(I, vtype=GRB.INTEGER, name="x") 


    # Set objective - total number of boards used
    m.setObjective(sum(x[i] for i in I ), GRB.MINIMIZE)

    # Demand constraints:
    m.addConstrs((sum(P[i][j]*x[i] for i in I) >= D[j] for j in J)
                 , "Demand")


    # Optimize model
    m.optimize()

# %%
import numpy as np
100*np.array(D)
# Out:
# array([1200, 1500, 2200])

# %%
board_time = []

# %%
board_time += [5]
board_time
# Out:
# [5, 5]

# %%
import time
scale = [1,10,100,500,1000]

board_time = []
for s in scale:
    tic = time.perf_counter()
    board_based(s*np.array(D))
    toc = time.perf_counter()
    board_time += [toc-tic]
board_time
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 67 rows, 64 columns and 192 nonzeros
# Model fingerprint: 0xee67ce00
# Variable types: 0 continuous, 64 integer (16 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Found heuristic solution: objective 15.0000000
# Presolve time: 0.00s
# Presolved: 67 rows, 64 columns, 192 nonzeros
# Variable types: 0 continuous, 64 integer (16 binary)
#
# Root relaxation: objective 7.333333e+00, 93 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    7.33333    0   43   15.00000    7.33333  51.1%     -    0s
# H    0     0                      14.0000000    7.33333  47.6%     -    0s
#      0     0    8.99414    0   38   14.00000    8.99414  35.8%     -    0s
#      0     0   11.13558    0   26   14.00000   11.13558  20.5%     -    0s
#      0     0   11.13558    0   28   14.00000   11.13558  20.5%     -    0s
#      0     0   11.34694    0   28   14.00000   11.34694  19.0%     -    0s
#      0     2   11.34694    0   28   14.00000   11.34694  19.0%     -    0s
#
# Explored 8 nodes (344 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 14 15 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 619 rows, 616 columns and 1848 nonzeros
# Model fingerprint: 0x5b0a652d
# Variable types: 0 continuous, 616 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+02]
# Presolve time: 0.00s
# Presolved: 619 rows, 616 columns, 1848 nonzeros
# Variable types: 0 continuous, 616 integer (154 binary)
# Found heuristic solution: objective 141.0000000
#
# Root relaxation: objective 7.333333e+01, 1016 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   73.33333    0  424  141.00000   73.33333  48.0%     -    0s
#      0     0   96.16955    0  334  141.00000   96.16955  31.8%     -    0s
#      0     0  128.94505    0  213  141.00000  128.94505  8.55%     -    0s
#      0     0  128.94505    0  249  141.00000  128.94505  8.55%     -    0s
#      0     0  128.94505    0  248  141.00000  128.94505  8.55%     -    0s
#      0     2  128.94505    0  248  141.00000  128.94505  8.55%     -    0s
# H  518   385                     140.0000000  135.00000  3.57%  22.0    0s
# H  621   443                     139.0000000  135.00000  2.88%  22.5    0s
# H 1355   763                     138.0000000  137.31111  0.50%  17.3    0s
#
# Cutting planes:
#   Gomory: 14
#   Projected implied bound: 44
#   MIR: 147
#   StrongCG: 46
#
# Explored 1355 nodes (29515 simplex iterations) in 0.60 seconds (0.56 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: 138 139 140 141
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.380000000000e+02, best bound 1.380000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 6139 rows, 6136 columns and 18408 nonzeros
# Model fingerprint: 0x28b5c362
# Variable types: 0 continuous, 6136 integer (1534 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+03]
# Presolve time: 0.01s
# Presolved: 6139 rows, 6136 columns, 18408 nonzeros
# Variable types: 0 continuous, 6136 integer (1534 binary)
# Found heuristic solution: objective 1409.0000000
#
# Root relaxation: objective 7.333333e+02, 11551 iterations, 0.47 seconds (0.66 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  733.33333    0 4246 1409.00000  733.33333  48.0%     -    0s
# H    0     0                    1407.0000000  733.33333  47.9%     -    0s
# H    0     0                    1405.0000000  930.93128  33.7%     -    1s
# H    0     0                    1401.0000000  930.93128  33.6%     -    1s
#      0     0  930.93128    0 3312 1401.00000  930.93128  33.6%     -    1s
# H    0     0                    1397.0000000 1186.75849  15.0%     -    2s
#      0     0 1188.45546    0 2280 1397.00000 1188.45546  14.9%     -    2s
#      0     0 1206.66945    0 2188 1397.00000 1206.66945  13.6%     -    2s
#      0     0 1326.44396    0 1693 1397.00000 1326.44396  5.05%     -    2s
# H    0     0                    1395.0000000 1337.83596  4.10%     -    3s
#      0     0 1337.83596    0 1960 1395.00000 1337.83596  4.10%     -    3s
#      0     0 1342.10526    0 2021 1395.00000 1342.10526  3.79%     -    3s
#      0     0 1342.10526    0 2012 1395.00000 1342.10526  3.79%     -    3s
#      0     0 1345.74841    0 1189 1395.00000 1345.74841  3.53%     -    4s
#      0     0 1356.31810    0 1332 1395.00000 1356.31810  2.77%     -    7s
#      0     0 1358.53175    0 1245 1395.00000 1358.53175  2.61%     -    7s
#      0     0 1358.62508    0 1234 1395.00000 1358.62508  2.61%     -    7s
#      0     0 1373.18889    0  569 1395.00000 1373.18889  1.56%     -    7s
#      0     0 1373.33333    0  500 1395.00000 1373.33333  1.55%     -    7s
#      0     0 1373.33333    0  466 1395.00000 1373.33333  1.55%     -    8s
#      0     0 1373.33333    0  473 1395.00000 1373.33333  1.55%     -    8s
#      0     0 1373.33333    0  435 1395.00000 1373.33333  1.55%     -    8s
#      0     0 1373.33333    0  435 1395.00000 1373.33333  1.55%     -    8s
#      0     2 1373.33333    0  435 1395.00000 1373.33333  1.55%     -    9s
#      7     2 1373.33333    4  542 1395.00000 1373.33333  1.55%  1095   10s
#    242     2 1373.33333  121  421 1395.00000 1373.33333  1.55%  76.8   15s
# H  504     2                    1390.0000000 1373.33333  1.20%  37.7   18s
#    505     2 1373.33333  253  421 1390.00000 1373.33333  1.20%  37.6   20s
# H  530     2                    1386.0000000 1373.33333  0.91%  35.9   20s
# H  556     2                    1380.0000000 1373.33333  0.48%  34.2   21s
# H  583     2                    1377.0000000 1373.33333  0.27%  32.8   21s
# H  635     2                    1376.0000000 1373.33333  0.19%  30.3   22s
# H  662     2                    1375.0000000 1373.33333  0.12%  29.4   23s
# H  689     2                    1374.0000000 1373.33333  0.05%  28.3   24s
#
# Cutting planes:
#   Gomory: 122
#   MIR: 3345
#   StrongCG: 647
#   Flow cover: 307
#   Mod-K: 38
#   Relax-and-lift: 900
#
# Explored 691 nodes (68363 simplex iterations) in 24.17 seconds (46.60 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 1374 1375 1376 ... 1401
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.374000000000e+03, best bound 1.374000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 30671 rows, 30668 columns and 92004 nonzeros
# Model fingerprint: 0x21161071
# Variable types: 0 continuous, 30668 integer (7667 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 1e+04]
# Presolve time: 0.12s
# Presolved: 30671 rows, 30668 columns, 92004 nonzeros
# Variable types: 0 continuous, 30668 integer (7667 binary)
# Found heuristic solution: objective 7042.0000000
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    39397    2.6647552e+03   8.720708e+03   0.000000e+00      5s
#    48305    3.6666667e+03   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 3.666667e+03, 48305 iterations, 6.49 seconds (11.39 work units)
# Total elapsed time = 18.72s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3666.66667    0 21365 7042.00000 3666.66667  47.9%     -   18s
# H    0     0                    7028.0000000 3666.66667  47.8%     -   19s
# H    0     0                    7020.0000000 3666.66667  47.8%     -   29s
#      0     0 3666.66667    0 21248 7020.00000 3666.66667  47.8%     -   29s
# H    0     0                    7001.0000000 4288.29511  38.7%     -   47s
# H    0     0                    6991.0000000 4288.29511  38.7%     -   47s
#      0     0 4290.26219    0 18506 6991.00000 4290.26219  38.6%     -   47s
#      0     0 5219.39443    0 15087 6991.00000 5219.39443  25.3%     -   65s
#      0     0 6037.88653    0 11075 6991.00000 6037.88653  13.6%     -   72s
#      0     0 6037.88653    0 11060 6991.00000 6037.88653  13.6%     -   72s
# H    0     0                    6987.0000000 6037.88653  13.6%     -   73s
# H    0     0                    6983.0000000 6320.16747  9.49%     -   98s
# H    0     0                    6968.0000000 6320.16747  9.30%     -   98s
#      0     0 6320.16747    0 8092 6968.00000 6320.16747  9.30%     -   98s
# H    0     0                    6958.0000000 6341.63081  8.86%     -  106s
# H    0     0                    6951.0000000 6341.63081  8.77%     -  106s
# H    0     0                    6940.0000000 6341.63081  8.62%     -  106s
# H    0     0                    6920.0000000 6341.63081  8.36%     -  106s
#      0     0 6341.63081    0 10778 6920.00000 6341.63081  8.36%     -  106s
# H    0     0                    6904.0000000 6570.43007  4.83%     -  112s
#      0     0 6570.43007    0 10151 6904.00000 6570.43007  4.83%     -  112s
#      0     0 6696.41694    0 10294 6904.00000 6696.41694  3.01%     -  116s
#      0     0 6710.52632    0 10055 6904.00000 6710.52632  2.80%     -  118s
#      0     0 6710.52632    0 10108 6904.00000 6710.52632  2.80%     -  118s
#      0     0 6710.52632    0 9813 6904.00000 6710.52632  2.80%     -  128s
# H    0     0                    6871.0000000 6710.52632  2.34%     -  206s
# H    0     0                    6870.0000000 6710.52632  2.32%     -  206s
#      0     0 6710.52632    0 8040 6870.00000 6710.52632  2.32%     -  206s
#      0     0 6710.52632    0 8824 6870.00000 6710.52632  2.32%     -  215s
#      0     0 6768.74482    0 5686 6870.00000 6768.74482  1.47%     -  219s
#      0     0 6798.08683    0 6133 6870.00000 6798.08683  1.05%     -  223s
#      0     0 6799.28828    0 6421 6870.00000 6799.28828  1.03%     -  227s
#      0     0 6857.15608    0 3031 6870.00000 6857.15608  0.19%     -  243s
#      0     0 6858.03333    0 3350 6870.00000 6858.03333  0.17%     -  246s
#      0     0 6866.66667    0 2211 6870.00000 6866.66667  0.05%     -  250s
#      0     0 6866.66667    0 2410 6870.00000 6866.66667  0.05%     -  252s
#      0     0 6866.66667    0 1657 6870.00000 6866.66667  0.05%     -  255s
#      0     0 6866.66667    0 1700 6870.00000 6866.66667  0.05%     -  257s
#      0     0 6866.66667    0 1363 6870.00000 6866.66667  0.05%     -  271s
#      0     0 6866.66667    0 1943 6870.00000 6866.66667  0.05%     -  274s
#      0     0 6866.66667    0 1455 6870.00000 6866.66667  0.05%     -  285s
#      0     0 6866.66667    0 1455 6870.00000 6866.66667  0.05%     -  290s
#      0     2 6866.66667    0 1455 6870.00000 6866.66667  0.05%     -  353s
#      3     2 6866.66667    2 1619 6870.00000 6866.66667  0.05%  5743  358s
#      5     2 infeasible    3      6870.00000 6866.66667  0.05%  3446  366s
#      7     2 6866.66667    4 2439 6870.00000 6866.66667  0.05%  4841  373s
#      9     2 infeasible    5      6870.00000 6866.66667  0.05%  3765  376s
#     11     2 6866.66667    6 2755 6870.00000 6866.66667  0.05%  3936  381s
#     15     2 6866.66667    8 2271 6870.00000 6866.66667  0.05%  3517  392s
#     17     2 infeasible    9      6870.00000 6866.66667  0.05%  3103  395s
#     23     2 6866.66667   12 2105 6870.00000 6866.66667  0.05%  2926  400s
#     33     2 infeasible   17      6870.00000 6866.66667  0.05%  2382  405s
#     55     2 6866.66667   28 1825 6870.00000 6866.66667  0.05%  1622  410s
#     75     2 6866.66667   38 1824 6870.00000 6866.66667  0.05%  1355  415s
#     95     2 6866.66667   48 1825 6870.00000 6866.66667  0.05%  1313  420s
#    115     2 6866.66667   58 1825 6870.00000 6866.66667  0.05%  1202  425s
#    128     3 6866.66667   65 1822 6870.00000 6866.66667  0.05%  1177  430s
#    136     2 6866.66667   69 1822 6870.00000 6866.66667  0.05%  1152  435s
#    145     3 infeasible   73      6870.00000 6866.66667  0.05%  1096  440s
#    152     3 infeasible   76      6870.00000 6866.66667  0.05%  1087  446s
#    160     3 infeasible   80      6870.00000 6866.66667  0.05%  1075  451s
#    168     3 infeasible   84      6870.00000 6866.66667  0.05%  1055  457s
#    176     3 infeasible   88      6870.00000 6866.66667  0.05%  1008  462s
#    180     3 6866.66667   91 1837 6870.00000 6866.66667  0.05%   985  465s
#    190     3 6866.66667   96 1836 6870.00000 6866.66667  0.05%   934  471s
#    198     3 6866.66667  100 1836 6870.00000 6866.66667  0.05%   896  477s
#    202     3 infeasible  101      6870.00000 6866.66667  0.05%   878  480s
#    210     3 infeasible  105      6870.00000 6866.66667  0.05%   845  485s
#    222     4 6866.66667  112 1839 6870.00000 6866.66667  0.05%   799  492s
#    227     2 infeasible  113      6870.00000 6866.66667  0.05%   782  495s
#    243     2 6866.66667  123 1836 6870.00000 6866.66667  0.05%   730  502s
#    252     4 6866.66667  127 1835 6870.00000 6866.66667  0.05%   704  507s
#    257     4 infeasible  128      6870.00000 6866.66667  0.05%   690  510s
#    269     2 infeasible  134      6870.00000 6866.66667  0.05%   660  516s
#    279     4 infeasible  139      6870.00000 6866.66667  0.05%   636  521s
#    291     4 infeasible  145      6870.00000 6866.66667  0.05%   610  527s
#    297     4 6866.66667  150 1836 6870.00000 6866.66667  0.05%   598  530s
#    303     4 infeasible  151      6870.00000 6866.66667  0.05%   586  535s
#    316     3 infeasible  157      6870.00000 6866.66667  0.05%   562  542s
#    324     5 6866.66667  163 1835 6870.00000 6866.66667  0.05%   548  546s
#    330     4 infeasible  164      6870.00000 6866.66667  0.05%   538  551s
#    337     5 6866.66667  170 1835 6870.00000 6866.66667  0.05%   527  556s
#    344     5 infeasible  171      6870.00000 6866.66667  0.05%   516  560s
#    352     5 6866.66667  178 1835 6870.00000 6866.66667  0.05%   504  565s
#    360     5 infeasible  179      6870.00000 6866.66667  0.05%   493  572s
#    368     5 6866.66667  186 1839 6870.00000 6866.66667  0.05%   482  577s
#    376     3 infeasible  187      6870.00000 6866.66667  0.05%   472  581s
#    384     5 6866.66667  193 1835 6870.00000 6866.66667  0.05%   462  586s
#    390     6 infeasible  194      6870.00000 6866.66667  0.05%   455  590s
#    399     5 6866.66667  202 1839 6870.00000 6866.66667  0.05%   445  595s
#    417     2 6866.66667  210 1839 6870.00000 6866.66667  0.05%   426  603s
#
# Cutting planes:
#   Gomory: 125
#   MIR: 15686
#   StrongCG: 2917
#   Flow cover: 1043
#   Mod-K: 69
#   Relax-and-lift: 3757
#
# Explored 421 nodes (520669 simplex iterations) in 604.09 seconds (646.68 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 10: 6870 6871 6904 ... 6987
#
# Solve interrupted
# Best objective 6.870000000000e+03, best bound 6.867000000000e+03, gap 0.0437%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 61339 rows, 61336 columns and 184008 nonzeros
# Model fingerprint: 0xbe72d5cb
# Variable types: 0 continuous, 61336 integer (15334 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+01, 2e+04]
# Presolve time: 0.49s
# Presolved: 61339 rows, 61336 columns, 184008 nonzeros
# Variable types: 0 continuous, 61336 integer (15334 binary)
# Found heuristic solution: objective 14084.000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 PPushes remaining with PInf 0.0000000e+00                 8s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.1542104e-13      8s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    38338    7.3333333e+03   0.000000e+00   0.000000e+00      8s
# Concurrent spin time: 0.02s
#
# Solved with primal simplex
#
# Root relaxation: objective 7.333333e+03, 38338 iterations, 7.14 seconds (1.93 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7333.33333    0 43501 14084.0000 7333.33333  47.9%     -   37s
#      0     0          -    0      14084.0000 7333.33333  47.9%     -   49s
#
# Cutting planes:
#   Flow cover: 2636
#   Relax-and-lift: 1431
#
# Explored 1 nodes (47453 simplex iterations) in 49.94 seconds (27.16 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 14084
#
# Solve interrupted
# Best objective 1.408400000000e+04, best bound 7.334000000000e+03, gap 47.9267%
# [0.05170187800001713,
#  0.6256663809999736,
#  24.32711055799996,
#  605.110591016,
#  53.65000144800001]

# %%
pattern_time = []
pattern_scale = scale + [10000,100000,200000,400000,600000,800000,1000000]
for s in pattern_scale:
    tic = time.perf_counter()
    pattern_based(s*np.array(D))
    toc = time.perf_counter()
    pattern_time += [toc-tic]
pattern_time
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x9ffba881
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 2e+01]
# Found heuristic solution: objective 27.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+01, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   13.88889    0    2   27.00000   13.88889  48.6%     -    0s
# H    0     0                      15.0000000   13.88889  7.41%     -    0s
# H    0     0                      14.0000000   13.88889  0.79%     -    0s
#      0     0   13.88889    0    2   14.00000   13.88889  0.79%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 14 15 27
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.400000000000e+01, best bound 1.400000000000e+01, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x21862c28
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 2e+02]
# Found heuristic solution: objective 270.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+02, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  138.88889    0    2  270.00000  138.88889  48.6%     -    0s
# H    0     0                     140.0000000  138.88889  0.79%     -    0s
# H    0     0                     139.0000000  138.88889  0.08%     -    0s
#      0     0  138.88889    0    2  139.00000  138.88889  0.08%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 139 140 270
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.390000000000e+02, best bound 1.390000000000e+02, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x95120db6
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 2e+03]
# Found heuristic solution: objective 2700.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+03, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1388.88889    0    2 2700.00000 1388.88889  48.6%     -    0s
# H    0     0                    1390.0000000 1388.88889  0.08%     -    0s
# H    0     0                    1389.0000000 1388.88889  0.01%     -    0s
#      0     0 1388.88889    0    2 1389.00000 1388.88889  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1389 1390 2700
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.389000000000e+03, best bound 1.389000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x7021099e
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+03, 1e+04]
# Found heuristic solution: objective 13500.000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 6.944444e+03, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6944.44444    0    2 13500.0000 6944.44444  48.6%     -    0s
# H    0     0                    6945.0000000 6944.44444  0.01%     -    0s
#      0     0 6944.44444    0    2 6945.00000 6944.44444  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 6945 13500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.945000000000e+03, best bound 6.945000000000e+03, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x2a74d438
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+04, 2e+04]
# Found heuristic solution: objective 27000.000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 13888.8889    0    2 27000.0000 13888.8889  48.6%     -    0s
# H    0     0                    13890.000000 13888.8889  0.01%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 13890 27000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.389000000000e+04, best bound 1.388900000000e+04, gap 0.0072%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x8242f543
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+05, 2e+05]
# Found heuristic solution: objective 270000.00000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+05, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 138888.889    0    2 270000.000 138888.889  48.6%     -    0s
# H    0     0                    138890.00000 138888.889  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 138890 270000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.388900000000e+05, best bound 1.388890000000e+05, gap 0.0007%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0xfd7e44b9
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+06, 2e+06]
# Found heuristic solution: objective 2700000.0000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+06, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1388888.89    0    2 2700000.00 1388888.89  48.6%     -    0s
# H    0     0                    1388890.0000 1388888.89  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1.38889e+06 2.7e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.388890000000e+06, best bound 1.388888888889e+06, gap 0.0001%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x443e75ef
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+06, 4e+06]
# Found heuristic solution: objective 5400000.0000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 2.777778e+06, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2777777.78    0    2 5400000.00 2777777.78  48.6%     -    0s
# H    0     0                    2777778.0000 2777777.78  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 2.77778e+06 5.4e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.777778000000e+06, best bound 2.777777777778e+06, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x34d1dd9e
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+06, 9e+06]
# Found heuristic solution: objective 1.080000e+07
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 5.555556e+06, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5555555.56    0    2 1.0800e+07 5555555.56  48.6%     -    0s
# H    0     0                    5555556.0000 5555555.56  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 5.55556e+06 1.08e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.555556000000e+06, best bound 5.555555555556e+06, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0x095e69d3
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+06, 1e+07]
# Found heuristic solution: objective 1.620000e+07
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 8.333333e+06, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 8333333.33    0    1 1.6200e+07 8333333.33  48.6%     -    0s
# H    0     0                    8333334.0000 8333333.33  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 8.33333e+06 1.62e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.333334000000e+06, best bound 8.333333333333e+06, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0xa37e99c4
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+07, 2e+07]
# Found heuristic solution: objective 2.160000e+07
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.111111e+07, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.1111e+07    0    2 2.1600e+07 1.1111e+07  48.6%     -    0s
# H    0     0                    1.111111e+07 1.1111e+07  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1.11111e+07 2.16e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.111111200000e+07, best bound 1.111111111111e+07, gap 0.0000%
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[x86])
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 3 rows, 10 columns and 18 nonzeros
# Model fingerprint: 0xec9e70f1
# Variable types: 0 continuous, 10 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+07, 2e+07]
# Found heuristic solution: objective 2.700000e+07
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 3 rows, 9 columns, 16 nonzeros
# Variable types: 0 continuous, 9 integer (0 binary)
#
# Root relaxation: objective 1.388889e+07, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.3889e+07    0    2 2.7000e+07 1.3889e+07  48.6%     -    0s
# H    0     0                    1.388889e+07 1.3889e+07  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 1.38889e+07 2.7e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.388889000000e+07, best bound 1.388888888889e+07, gap 0.0000%
# [0.026882806999765307,
#  0.0251129220000621,
#  0.02892942900007256,
#  0.025811221999902045,
#  0.023618580999936967,
#  0.020167440000022907,
#  0.022010847999808902,
#  0.018603488999815454,
#  0.020421865000116668,
#  0.01816654300000664,
#  0.017980764999720122,
#  0.022277012999893486]

# %%
board_time[4] = 600

# %%
scale
# Out:
# [1, 10, 100, 500, 1000]

# %%
import matplotlib.pyplot as plt

plt.scatter(scale[0:4],pattern_time[0:4], label = r'Pattern Formulation')
plt.scatter(scale[0:4],board_time[0:4], label = r'Board Formulation')
plt.title("Comparing Models")
plt.ylabel("Seconds")
plt.xlabel("Multiplier on Demand")
plt.legend() 
plt.show()
plt.savefig("Comparing_Cutting_stock.pdf")

# %%
import matplotlib.pyplot as plt

plt.scatter(pattern_scale,pattern_time, label = r'Pattern Formulation')
#plt.scatter(scale,board_time, label = r'Board Formulation')
plt.title("Pattern Scale on Large Demands")
plt.ylabel("Seconds")
plt.xlabel("Multiplier on Demand")
plt.ylim((0, 0.2))
plt.legend() 
plt.show()
plt.savefig("pattern_Cutting_stock.pdf")

# %%
pattern_time
# Out:
# [0.026882806999765307,
#  0.0251129220000621,
#  0.02892942900007256,
#  0.025811221999902045,
#  0.023618580999936967,
#  0.020167440000022907,
#  0.022010847999808902,
#  0.018603488999815454,
#  0.020421865000116668,
#  0.01816654300000664,
#  0.017980764999720122,
#  0.022277012999893486]

# %%
[np.round(time,4) for time in pattern_time]
# Out:
# [0.0269,
#  0.0251,
#  0.0289,
#  0.0258,
#  0.0236,
#  0.0202,
#  0.022,
#  0.0186,
#  0.0204,
#  0.0182,
#  0.018,
#  0.0223]

# %%
board_time
# Out:
# [0.05170187800001713, 0.6256663809999736, 24.32711055799996, 600, 600]

# %%
pattern_scale
# Out:
# [1, 10, 100, 500, 1000, 10000, 100000, 200000, 400000, 600000, 800000, 1000000]
